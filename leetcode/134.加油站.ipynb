# %% [markdown]
# #### 目录 134.加油站
# * 原题描述
# * 第一遍解法
# * 网上解法
# * 优化自己的代码
# * 第二遍解法
#
# #### 1. 问题描述
#
# 贪心算法
#
# 在一条环路上有 N 个加油站，其中第 i 个加油站有汽油 gas[i] 升。
#
# 你有一辆油箱容量无限的的汽车，从第 i 个加油站开往第 i+1 个加油站需要消耗汽油 cost[i] 升。你从其中的一个加油站出发，开始时油箱为空。
#
# 如果你可以绕环路行驶一周，则返回出发时加油站的编号，否则返回 -1。
#
# * 说明:
#
# >如果题目有解，该答案即为唯一答案。
# 输入数组均为非空数组，且长度相同。
# 输入数组中的元素均为非负数。
#
# * 示例 1:
#
# >输入:
# gas  = [1,2,3,4,5]
# cost = [3,4,5,1,2]
# 输出: 3
# 解释:
# 从 3 号加油站(索引为 3 处)出发，可获得 4 升汽油。此时油箱有 = 0 + 4 = 4 升汽油
# 开往 4 号加油站，此时油箱有 4 - 1 + 5 = 8 升汽油
# 开往 0 号加油站，此时油箱有 8 - 2 + 1 = 7 升汽油
# 开往 1 号加油站，此时油箱有 7 - 3 + 2 = 6 升汽油
# 开往 2 号加油站，此时油箱有 6 - 4 + 3 = 5 升汽油
# 开往 3 号加油站，你需要消耗 5 升汽油，正好足够你返回到 3 号加油站。
# 因此，3 可为起始索引。
#
# * 示例 2:
#
# >输入:
# gas  = [2,3,4]
# cost = [3,4,3]
# 输出: -1
# 解释:
# 你不能从 0 号或 1 号加油站出发，因为没有足够的汽油可以让你行驶到下一个
# 油站。
# 我们从 2 号加油站出发，可以获得 4 升汽油。 此时油箱有 = 0 + 4 = 4 升汽油
# 开往 0 号加油站，此时油箱有 4 - 3 + 2 = 3 升汽油
# 开往 1 号加油站，此时油箱有 3 - 3 + 3 = 3 升汽油
# 你无法返回 2 号加油站，因为返程需要消耗 4 升汽油，但是你的油箱只有 3 升汽油。
# 因此，无论怎样，你都不可能绕环路行驶一周。
#
#
# #### 2、我的第一次解法 12.20
#
# **2.1 思路**
#
# * 两个问题，选择哪个点为出发点，车的油量大于两个加油站之间的耗油量
#
# * 选择出发点：选择gas[i]>cost[i]的地方为出发点
#
# * 选择出发电后，判断每一次油箱的油=上一加油站加的油 - 消耗的油 >0
#
# * 卡点：索引的方式  --切片重建
#
# **2.2 代码尝试**

# %%
class Solution:
    def canCompleteCircuit(self, gas: List[int], cost: List[int]) -> int:
        for i in range(len(gas)):
            if  gas[i]>=cost[i]:
                g =gas[i:] + gas[:i]
                c =cost[i:]+ cost[:i]
                print(g,c)
                for i in range(0,len(gas)):
                    have = g[0]-c[0]
                    have = have +g[i]-c[i]
                    if have <0:
                        result = -1
                        break
                    else:
                        result=gas.index(g[0])
        return(result)
## 解答错误，有个疑问break不是跳出单层循环？
## break是跳出单层循环，我代码错误的原因是return位置错误
## return 是返回数值，结束函数

# %% [markdown]
# **2.3 正确代码解析**
# * 解法一
#
# 把题目想复杂了
# 只需要满足sum(gas)>=sum(cost)，车子就可以绕一圈，因为是唯一解，
# 然后再就是找出第一个gas[i]>=cost[i],并且到最后值的求和依然大于0就行
#
#
# ```python
#
# class Solution(object):
#     def canCompleteCircuit(self, gas, cost):
#         """
#         :type gas: List[int]
#         :type cost: List[int]
#         :rtype: int
#         """
#         _station = 0
#         if sum(gas) - sum(cost) < 0:
#             return -1
#         else:
#             _sum = 0
#             for i in range(len(gas)):
#                 if gas[i] - cost[i] < 0 and _sum == 0:
#                     _station += 1
#                     continue
#                 _sum += gas[i] - cost[i]
#                 if _sum < 0: ## 找到gas[i]<cost[i]的的出发点
#                     _sum = 0
#                     _station = i+1
#
#             return _station
#
# ```
# * 解法二

# %% [markdown]
# **2.4 我的代码改进**

# %% [markdown]
# #### 3、相关知识讲解
