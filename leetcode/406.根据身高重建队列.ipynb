# %% [markdown]
# #### 目录
# * 原题描述 406.根据身高重建队列
# * 第一遍解法
# * 网上解法
# * 优化自己的代码
# * 第二遍解法
#
# #### 1. 问题描述
#
# **贪心算法**
#
# 假设有打乱顺序的一群人站成一个队列。 每个人由一个整数对(h, k)表示，其中h是这个人的身高，k是排在这个人前面且身高大于或等于h的人数。 编写一个算法来重建这个队列。
#
# 注意：
# 总人数少于1100人。
#
# * 示例
#
# > 输入:
# [[7,0], [4,4], [7,1], [5,0], [6,1], [5,2]]
# 输出:
# [[5,0], [7,0], [5,2], [6,1], [4,4], [7,1]]
#
#
# #### 2、我的第一次解法 12.19
#
# **2.1 思路**
#
# * 第一次排序按身高排序
# * 第二次比较实际位置，和k的值，
#
#
# **2.2 代码尝试**

# %%
class Solution:
    def reconstructQueue(self, people: List[List[int]]) -> List[List[int]]:
        #第一次排序，排序按照身高和前面的人数一起排序
        people.sort(reverse=True)
        print(people)
        for i,p in enumerate(people):
            if p[1] != i:
                people.pop(i)
                people.insert(p[1],p)
                print(people)
        
        return(people)
    
## 思路正确，先排序再插入，代码有漏洞
## 对身高进行排序之后，k也要按照大小排序

# %% [markdown]
# **2.3 正确代码解析**
# * 解法一
#
# 示例： [[7,0], [4,4], [7,1], [5,0], [6,1], [5,2]]
#
# 排序后： [[7,0], [7,1], [6,1], [5,0], [5,2], [4,4]]
#
# 开始插入：(第二个元素就是插入的位置)
# >[[7, 0]]
# [[7, 0], [7, 1]]
# [[7, 0], [6, 1], [7, 1]]
# [[5, 0], [7, 0], [6, 1], [7, 1]]
# [[5, 0], [7, 0], [5, 2], [6, 1], [7, 1]]
# [[5, 0], [7, 0], [5, 2], [6, 1], [4, 4], [7, 1]]
#
#
#
#
# ```python
# #先排序，在按照k进一步排序插入
#
# class Solution:
#     def reconstructQueue(self, people: List[List[int]]) -> List[List[int]]:
#         people.sort(key = lambda x: [-x[0], x[1]])
#         res = []
#         for p in people:
#             res.insert(p[1], p)
#         return res
#
#  #对比我的解法，我多了一步people.pop()，这一步可以省去
#
# ```
#
#
#
# * 解法二
#
# **2.4 我的代码改进**
#
# ```python
#
# class Solution:
#     def reconstructQueue(self, people: List[List[int]]) -> List[List[int]]:
#         #第一次排序，排序按照身高和前面的人数一起排序
#         people.sort(key = lambda x: [-x[0], x[1]])
#         print(people)
#         for i,p in enumerate(people):
#             if p[1] != i:
#                 people.pop(i)
#                 people.insert(p[1],p)
#                 print(people)
#
#         return(people)
# ##正确
#
# ```

# %% [markdown]
# #### 3、相关知识讲解
# ##### 3.1 sort()
#
# * 普通排序 iterable.sort()
#
# * 倒序排序  iterable.sort(reverse = True)
#            iterable.sort( key = lambda x : -x )
#
# * 按照元素的第i个域排序 iterable.sort(key = lambda x : x[i] )
