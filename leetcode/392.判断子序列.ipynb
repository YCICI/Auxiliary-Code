# %% [markdown]
# #### 目录
# * 原题描述  392.判断子序列
# * 第一遍解法
# * 网上解法
# * 优化自己的代码
# * 第二遍解法
#
# #### 1. 问题描述
#
# 给定字符串 s 和 t ，判断 s 是否为 t 的子序列。
#
# 你可以认为 s 和 t 中仅包含英文小写字母。字符串 t 可能会很长（长度 ~= 500,000），而 s 是个短字符串（长度 <=100）。
#
# 字符串的一个子序列是原始字符串删除一些（也可以不删除）字符而不改变剩余字符相对位置形成的新字符串。（例如，"ace"是"abcde"的一个子序列，而"aec"不是）
#
#
# * 示例 1:
# > s = "abc", t = "ahbgdc"
# 返回 true.
#
# * 示例 2:
# > s = "axc", t = "ahbgdc"
# 返回 false.
#
# #### 2、我的第一次解法 12.10
#
# **2.1 思路**
# * 首先 读清楚题，不仅是子集关系，还有顺序问题要考虑
# * 先遍历子序列，从母序列找相同的字符，没有就返回false，有的下一个字符就从母序列中对应的位置开始
#
#
# **2.2 代码尝试**

# %%
class Solution:
    def isSubsequence(self, s: str, t: str) -> bool:
        s = list(s)
        t = list(t)
        gap = 0
        result = 0
        for i in range(len(s)):
            for j in range(len(t)-gap):
                if s[i]==t[j+gap]:
                    gap = j+1
                    result+=1
                    break
        #print(result)
        #print(len(s))
        return(result == len(s))
# 答案错误，暂时我没有想到这个逻辑的错误点在哪
# 有个地方错了 gap应该等于这一次的索引加1 应该就是gap = j+gap+1

## 修改之后 超出时间限制

class Solution:
    def isSubsequence(self, s: str, t: str) -> bool:
        s = list(s)
        t = list(t)
        gap = 0
        result = 0
        for i in range(len(s)):
            for j in range(len(t)-gap):
                if s[i]==t[j+gap]:
                    #print('j+gap',j+gap)
                    gap = j+gap+1
                    result+=1
                    break
        #print(result)
        #print(len(s))
        return(result == len(s))

# %% [markdown]
# **2.3 正确代码解析**
# * 解法一
#
# ```python
#
# ## 我的思路没有错，但是代码写的太烂，索引值可以直接返回不知道，也没有想到可以利用切片
#
# class Solution:
#     def isSubsequence(self, s: str, t: str) -> bool:
#         for i in s:
#             if i in t:
#                 t = t[t.index(i)+1:]
#             else:
#                 return False
#         return True
#
# ```
#
# * 解法二
#
# ```python
#
# ## 第二种解法
# #第一步：在母序列t中按顺序遍历找s的字符
# #第二步：找到s中的字符后，删掉，继续查找下一个字符
#
# ## 这个方法的厉害之处就是 只需要1遍遍历
#
# def isSubsequence(s, t):
#     s = list(s)
#     for _t in t:
#         if not s:
#             return True
#         if _t == s[0]:
#             s.pop(0)
#
#     return not s
#
# ```
#
# **2.4 我的代码改进**
#
# #### 3、相关知识讲解
# 返回字符串索引值，不需要先变成列表，这样很麻烦，增加计算量，有t.index(i)返回 i的索引值
#
# 返回字符串中元素i的索引值：t.index(i)
